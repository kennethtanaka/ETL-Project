# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Extract CSVs into DataFrames

# %%
#us foreign aid 2000-2015
usa_file = "Resources/us_aid_reduced.csv"
usa_df = pd.read_csv(usa_file)
usa_df.head()
# Out:
#    Unnamed: 0  country_id country_name             region_name  \
# 0           0           4  Afghanistan  South and Central Asia
# 1           1           4  Afghanistan  South and Central Asia
# 2           2           4  Afghanistan  South and Central Asia
# 3           3           4  Afghanistan  South and Central Asia
# 4           4           4  Afghanistan  South and Central Asia
#
#     income_group_name  fiscal_year  current_amount  constant_amount
# 0  Low Income Country         2011      9941000000      11172173522
# 1  Low Income Country         2012      9243000000      10195234944
# 2  Low Income Country         2011      7840175215       8811165672
# 3  Low Income Country         2013      7764310985       8409304652
# 4  Low Income Country         2013      6928000000       7503519983

# %%
#life expectancy 2000-2015
# source https://www.kaggle.com/kumarajarshi/life-expectancy-who
life_file = "Resources/life_expectancy.csv"
life_df = pd.read_csv(life_file)
life_df.head()
# Out:
#        Country  Year      Status  Lifeexpectancy  AdultMortality  \
# 0  Afghanistan  2015  Developing            65.0           263.0
# 1  Afghanistan  2014  Developing            59.9           271.0
# 2  Afghanistan  2013  Developing            59.9           268.0
# 3  Afghanistan  2012  Developing            59.5           272.0
# 4  Afghanistan  2011  Developing            59.2           275.0
#
#    infantdeaths  Alcohol  percentageexpenditure  HepatitisB  Measles  ...  \
# 0            62     0.01              71.279624        65.0     1154  ...
# 1            64     0.01              73.523582        62.0      492  ...
# 2            66     0.01              73.219243        64.0      430  ...
# 3            69     0.01              78.184215        67.0     2787  ...
# 4            71     0.01               7.097109        68.0     3013  ...
#
#    Polio  Totalexpenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# 0    6.0              8.16        65.0       0.1  584.259210  33736494.0
# 1   58.0              8.18        62.0       0.1  612.696514    327582.0
# 2   62.0              8.13        64.0       0.1  631.744976  31731688.0
# 3   67.0              8.52        67.0       0.1  669.959000   3696958.0
# 4   68.0              7.87        68.0       0.1   63.537231   2978599.0
#
#    thinness1-19years  thinness5-9years  Incomecompositionofresources  \
# 0               17.2              17.3                         0.479
# 1               17.5              17.5                         0.476
# 2               17.7              17.7                         0.470
# 3               17.9              18.0                         0.463
# 4               18.2              18.2                         0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# # Transform Life Expectancy DataFrame

# %%
# Create a filtered dataframe from specific columns
life_cols = ["Country", "Year", "Status", "Lifeexpectancy", "AdultMortality", "infantdeaths","percentageexpenditure", "Measles", "BMI","under-fivedeaths","HIV/AIDS", "GDP", "Population", "Schooling"]
life_transformed= life_df[life_cols].copy()

# Rename the column headers
life_transformed = life_transformed.rename(columns={"Country": "country",
                                                        "Year": "year",
                                                         "Status": "status",
                                                        "Lifeexpectancy": "life_expectancy",
                                                        "AdultMortality": "adult_mortality",
                                                        "infantdeaths": "infant_deaths",
                                                        "percentageexpenditure": "percentage_expenditure",
                                                        "Measles": "measles",
                                                        "BMI": "bmi",
                                                        "under-fivedeaths": "under_five_death",
                                                        "HIV/AIDS": "hiv_aids", 
                                                        "GDP": "gdp", 
                                                        "Population": "population",
                                                        "Schooling": "schooling",                                                          
                                                      })

#take out spaces from country_name column
#remove data in parenthesis beside country name to match country name in US Aid data
life_transformed['country'] = life_transformed['country'].replace(' ','', regex=True).\
                              str.lower().str.split('(').str[0]


life_transformed.head()
# Out:
#        country  year      status  life_expectancy  adult_mortality  \
# 0  afghanistan  2015  Developing             65.0            263.0
# 1  afghanistan  2014  Developing             59.9            271.0
# 2  afghanistan  2013  Developing             59.9            268.0
# 3  afghanistan  2012  Developing             59.5            272.0
# 4  afghanistan  2011  Developing             59.2            275.0
#
#    infant_deaths  percentage_expenditure  measles   bmi  under_five_death  \
# 0             62               71.279624     1154  19.1                83
# 1             64               73.523582      492  18.6                86
# 2             66               73.219243      430  18.1                89
# 3             69               78.184215     2787  17.6                93
# 4             71                7.097109     3013  17.2                97
#
#    hiv_aids         gdp  population  schooling
# 0       0.1  584.259210  33736494.0       10.1
# 1       0.1  612.696514    327582.0       10.0
# 2       0.1  631.744976  31731688.0        9.9
# 3       0.1  669.959000   3696958.0        9.8
# 4       0.1   63.537231   2978599.0        9.5

# %%
life_transformed.count()
# Out:
# country                   2938
# year                      2938
# status                    2938
# life_expectancy           2928
# adult_mortality           2928
# infant_deaths             2938
# percentage_expenditure    2938
# measles                   2938
# bmi                       2904
# under_five_death          2938
# hiv_aids                  2938
# gdp                       2490
# population                2286
# schooling                 2775
# dtype: int64

# %% [markdown]
# # Transform US Foreign Aid DataFrame

# %%
# Create a filtered dataframe from specific columns
us_cols = ["country_id", "country_name", "region_name", "income_group_name", "fiscal_year", "current_amount", "constant_amount"]
us_transformed= usa_df[us_cols].copy()

#take out spaces from country_name column
us_transformed['country_name'] = us_transformed['country_name'].replace(' ','', regex=True).\
                                 replace('/','', regex=True).replace(',','', regex=True).replace('-','', regex=True).\
                                 str.lower().str.split('(').str[0]

us_transformed.head()
# Out:
#    country_id country_name             region_name   income_group_name  \
# 0           4  afghanistan  South and Central Asia  Low Income Country
# 1           4  afghanistan  South and Central Asia  Low Income Country
# 2           4  afghanistan  South and Central Asia  Low Income Country
# 3           4  afghanistan  South and Central Asia  Low Income Country
# 4           4  afghanistan  South and Central Asia  Low Income Country
#
#    fiscal_year  current_amount  constant_amount
# 0         2011      9941000000      11172173522
# 1         2012      9243000000      10195234944
# 2         2011      7840175215       8811165672
# 3         2013      7764310985       8409304652
# 4         2013      6928000000       7503519983

# %%
us_transformed.count()
# Out:
# country_id           790570
# country_name         790570
# region_name          790570
# income_group_name    635118
# fiscal_year          790570
# current_amount       790570
# constant_amount      790570
# dtype: int64

# %%
#group the us_aid data by country and year
us_group = us_transformed.groupby(['country_name', 'fiscal_year'])['current_amount'].sum().reset_index()
us_group.head()
# Out:
#   country_name  fiscal_year  current_amount
# 0  afghanistan         2000        54072046
# 1  afghanistan         2001       132725398
# 2  afghanistan         2002       908765271
# 3  afghanistan         2003      1687162336
# 4  afghanistan         2004      3180036437

# %% [markdown]
# # Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/life_expect_us_aid"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "life_expect_us_aid" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2251         """
#    2252
# -> 2253         with self._optional_conn_ctx_manager(connection) as conn:
#    2254             if not schema:
#    2255                 schema = self.dialect.default_schema_name
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2035     def _optional_conn_ctx_manager(self, connection=None):
#    2036         if connection is None:
# -> 2037             with self._contextual_connect() as conn:
#    2038                 yield conn
#    2039         else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2237         return self._connection_cls(
#    2238             self,
# -> 2239             self._wrap_pool_connect(self.pool.connect, None),
#    2240             close_with_result=close_with_result,
#    2241             **kwargs
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "life_expect_us_aid" does not exist
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# # Load DataFrames into database

# %%
life_transformed.to_sql(name='life_expectancy', con=engine, if_exists='append', index=True)

# %%
us_group.to_sql(name='us_aid', con=engine, if_exists='append', index=True)

# %% [markdown]
# # Confirm data has been added by querying the life table

# %%
pd.read_sql_query('select * from life_expectancy', con=engine).head()

# %% [markdown]
# # Confirm data has been added by querying the us table

# %%
pd.read_sql_query('select * from us_aid', con=engine).head()

# %% [markdown]
# # Confirm data has been added  by querying the joined table

# %%
joined_table = pd.read_sql_query('select * from joined', con=engine)
joined_table.head()

# %% [markdown]
# # Export the joined table to csv

# %%
joined_table.to_csv('life_aid_2000_2015.csv')
